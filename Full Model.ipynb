# %% [markdown]
# #Importo librerias

# %%
from google.colab import drive
drive.mount('/gdrive')
# Out:
# Mounted at /gdrive

# %%
import pandas as pd
# !pip install pandas_summary
from pandas_summary import DataFrameSummary
import numpy as np
import datetime
# !pip install isoweek
from isoweek import Week
from matplotlib import pyplot as plt
from sklearn.preprocessing import LabelEncoder, StandardScaler
# !pip install sklearn_pandas
from sklearn_pandas import DataFrameMapper

# Para importar el Helper
# %cd "/gdrive/Shareddrives/Redes de Piluchina/TP 2_final"
# !pip install import-ipynb
import import_ipynb
from Helper import *
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting pandas_summary
#   Downloading pandas_summary-0.2.0-py2.py3-none-any.whl (5.2 kB)
# Collecting datatile
#   Downloading datatile-1.0.3-py3-none-any.whl (6.0 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.21.6)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.3.5)
# Collecting traceml<1.1
#   Downloading traceml-1.0.3-py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 7.1 MB/s
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Installing collected packages: traceml, datatile, pandas-summary
# Successfully installed datatile-1.0.3 pandas-summary-0.2.0 traceml-1.0.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting isoweek
#   Downloading isoweek-1.3.3-py2.py3-none-any.whl (7.1 kB)
# Installing collected packages: isoweek
# Successfully installed isoweek-1.3.3
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.3.5)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.0.2)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.21.6)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.7.3)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2022.5)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (3.1.0)
# /gdrive/Shareddrives/Redes de Piluchina/TP 2_final
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting import-ipynb
#   Downloading import_ipynb-0.1.4-py3-none-any.whl (4.1 kB)
# Requirement already satisfied: IPython in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (7.9.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.7/dist-packages (from import-ipynb) (5.7.0)
# Requirement already satisfied: prompt-toolkit<2.1.0,>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (2.0.10)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (5.1.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.2.0)
# Requirement already satisfied: pexpect in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.8.0)
# Requirement already satisfied: decorator in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (57.4.0)
# Collecting jedi>=0.10
#   Downloading jedi-0.18.1-py2.py3-none-any.whl (1.6 MB)
#      |████████████████████████████████| 1.6 MB 7.4 MB/s
# Requirement already satisfied: pygments in /usr/local/lib/python3.7/dist-packages (from IPython->import-ipynb) (2.6.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.7/dist-packages (from jedi>=0.10->IPython->import-ipynb) (0.8.3)
# Requirement already satisfied: six>=1.9.0 in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (1.15.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.7/dist-packages (from prompt-toolkit<2.1.0,>=2.0.0->IPython->import-ipynb) (0.2.5)
# Requirement already satisfied: jupyter-core in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.11.2)
# Requirement already satisfied: fastjsonschema in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (2.16.2)
# Requirement already satisfied: importlib-metadata>=3.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.13.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.7/dist-packages (from nbformat->import-ipynb) (4.3.3)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->nbformat->import-ipynb) (3.9.0)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata>=3.6->nbformat->import-ipynb) (4.1.1)
# Requirement already satisfied: attrs>=17.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (22.1.0)
# Requirement already satisfied: importlib-resources>=1.4.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (5.10.0)
# Requirement already satisfied: pyrsistent!=0.17.0,!=0.17.1,!=0.17.2,>=0.14.0 in /usr/local/lib/python3.7/dist-packages (from jsonschema>=2.6->nbformat->import-ipynb) (0.18.1)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.7/dist-packages (from pexpect->IPython->import-ipynb) (0.7.0)
# Installing collected packages: jedi, import-ipynb
# Successfully installed import-ipynb-0.1.4 jedi-0.18.1
# importing Jupyter notebook from Helper.ipynb
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas_summary in /usr/local/lib/python3.7/dist-packages (0.2.0)
# Requirement already satisfied: datatile in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.0.3)
# Requirement already satisfied: pandas in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.3.5)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from pandas_summary) (1.21.6)
# Requirement already satisfied: traceml<1.1 in /usr/local/lib/python3.7/dist-packages (from datatile->pandas_summary) (1.0.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas->pandas_summary) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas->pandas_summary) (1.15.0)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: isoweek in /usr/local/lib/python3.7/dist-packages (1.3.3)
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: sklearn_pandas in /usr/local/lib/python3.7/dist-packages (1.8.0)
# Requirement already satisfied: pandas>=0.11.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.3.5)
# Requirement already satisfied: numpy>=1.6.1 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.21.6)
# Requirement already satisfied: scikit-learn>=0.15.0 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.0.2)
# Requirement already satisfied: scipy>=0.14 in /usr/local/lib/python3.7/dist-packages (from sklearn_pandas) (1.7.3)
# Requirement already satisfied: python-dateutil>=2.7.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2.8.2)
# Requirement already satisfied: pytz>=2017.3 in /usr/local/lib/python3.7/dist-packages (from pandas>=0.11.0->sklearn_pandas) (2022.5)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7.3->pandas>=0.11.0->sklearn_pandas) (1.15.0)
# Requirement already satisfied: joblib>=0.11 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.7/dist-packages (from scikit-learn>=0.15.0->sklearn_pandas) (3.1.0)

# %%
from tensorflow.compat.v1 import ConfigProto
from tensorflow.compat.v1 import InteractiveSession
config = ConfigProto()
config.gpu_options.allow_growth = True
session = InteractiveSession(config=config)

# %%
import pandas as pd
import numpy as np
import datetime
from pandas_summary import DataFrameSummary

# %%
from tensorflow.keras.utils import to_categorical

# %%
df = pd.read_feather('/gdrive/Shareddrives/Redes de Piluchina/TP 2_final/train_normalized_data.fth')
df_test = pd.read_feather('/gdrive/Shareddrives/Redes de Piluchina/TP 2_final/test_normalized_data.fth')

# %%
cat_vars = ['Store', 'DayOfWeek', 'Year', 'Month', 'Day', 'StateHoliday', 'CompetitionMonthsOpen', 'Promo2Weeks', 
            'StoreType', 'Assortment', 'PromoInterval', 'CompetitionOpenSinceYear', 'Promo2SinceYear', 'State', 
            'Week', 'Events', 'Promo_fw', 'Promo_bw', 'StateHoliday_bool_fw', 'StateHoliday_bool_bw', 'SchoolHoliday_fw', 'SchoolHoliday_bw']

cat_vars = ['Store', 'DayOfWeek']

# %%
contin_vars = ['CompetitionDistance', 
   'Max_TemperatureC', 'Mean_TemperatureC', 'Min_TemperatureC', 'Precipitationmm',
   'Max_Humidity', 'Mean_Humidity', 'Min_Humidity', 'Max_Wind_SpeedKm_h', 
   'Mean_Wind_SpeedKm_h', 'CloudCover', 'trend', 'trend_DE',
   'AfterStateHoliday_bool', 'BeforeStateHoliday_bool', 'Promo', 'SchoolHoliday', 'StateHoliday_bool']
contin_vars = ['BeforeStateHoliday_bool', 'Max_TemperatureC']

# %%
uniques = DataFrameSummary(df[cat_vars]).summary().loc[['uniques']]

# %%
uniques.T
# Out:
#           uniques
# Store        1115
# DayOfWeek       7

# %% [markdown]
# #Asignación de dimensión de embeddings

# %%
cat_var_dict = {'Store': 50, 'DayOfWeek': 2, 'Year': 2, 'Month': 2,
'Day': 10, 'StateHoliday': 2, 'CompetitionMonthsOpen': 2,
'Promo2Weeks': 1, 'StoreType': 2, 'Assortment': 3, 'PromoInterval': 3,
'CompetitionOpenSinceYear': 4, 'Promo2SinceYear': 4, 'State': 6,
'Week': 25, 'Events': 4, 'Promo_fw': 1,
'Promo_bw': 1, 'StateHoliday_bool_fw': 1,
'StateHoliday_bool_bw': 1, 'SchoolHoliday_fw': 1,
'SchoolHoliday_bw': 1}

# %%
for v in cat_vars:
    uniques_ = df[v].unique()
    uniques_.sort()
    print(v, cat_var_dict[v], len(uniques_), uniques_)
    print()
# Out:
# Store 50 1115 [   0    1    2 ... 1112 1113 1114]
#
# DayOfWeek 2 7 [0 1 2 3 4 5 6]

# %% [markdown]
# #Definicion del modelo

# %%
add_customers = True
log_output = False
output_activation = 'linear'

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.layers import Embedding, Input, Flatten, Concatenate, Dense, BatchNormalization, Activation, LeakyReLU, Dropout
from tensorflow.keras.regularizers import l2

# %%
def get_cat_vars_model(cat_vars, uniques, cat_var_dict):
    cat_vars_embed_outs = []
    cat_var_inputs = []
    for cat_var in cat_vars:
        cat_var_in = Input(shape=(1,), name=f"{cat_var}_input")
        cat_var_inputs.append(cat_var_in)
        embed_out = Embedding(uniques[cat_var][0], cat_var_dict[cat_var], name=f'{cat_var}_Embed')(cat_var_in)
        flatten_out = Flatten(name=f"{cat_var}_flat")(embed_out)
        cat_vars_embed_outs.append(flatten_out)
    return cat_var_inputs, cat_vars_embed_outs

def get_cont_vars_input(contin_vars, dense_layer=False):
    cont_vars_inputs = []
    cont_vars_outputs = []
    for cont_var in contin_vars:
        cont_var_in = Input(shape=(1,), name=f"{cont_var}_input")
        cont_vars_inputs.append(cont_var_in)
        if dense_layer:
            cont_var_out = Dense(1, name=f"{cont_var}_input", activation = 'linear')(cont_var_in)
            cont_vars_outputs.append(cont_var_out)
        else:
            cont_vars_outputs.append(cont_var_in)
    return cont_vars_inputs, cont_vars_outputs

# %%
cat_var_inputs, cat_vars_embed_outs = get_cat_vars_model(cat_vars, uniques, cat_var_dict)
cont_vars_inputs,  cont_vars_outs= get_cont_vars_input(contin_vars)

# %%
cat_vars_embed_outs
cat_var_inputs
cont_vars_inputs
cont_vars_outs
# Out:
# [<KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'BeforeStateHoliday_bool_input')>,
#  <KerasTensor: shape=(None, 1) dtype=float32 (created by layer 'Max_TemperatureC_input')>]

# %%
first_hidden_units = 1000
second_hidden_units = 500
l2_lambda = 1e-3
merged = Concatenate(name='All_Concatenate')(cat_vars_embed_outs + cont_vars_inputs)
x = Dense(first_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(merged)
# x = BatchNormalization()(x)
x = Activation('relu')(x)
# x = LeakyReLU()(x)
x = Dense(second_hidden_units, kernel_initializer="uniform", kernel_regularizer=l2(l2_lambda))(x)
# x = BatchNormalization()(x)
x = Activation('relu')(x)
# x = LeakyReLU()(x)

output_1 = Dense(1, name='Sales', activation=output_activation)(x)
output_2 = Dense(1, name='Customers', activation=output_activation)(x)

# %%
if add_customers:
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1, output_2])
else: 
    model = Model(cat_var_inputs + cont_vars_inputs, [output_1])

# %%
model.summary()
# Out:
# Model: "model_2"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Store_input (InputLayer)       [(None, 1)]          0           []
#
#  DayOfWeek_input (InputLayer)   [(None, 1)]          0           []
#
#  Store_Embed (Embedding)        (None, 1, 50)        55750       ['Store_input[0][0]']
#
#  DayOfWeek_Embed (Embedding)    (None, 1, 2)         14          ['DayOfWeek_input[0][0]']
#
#  Store_flat (Flatten)           (None, 50)           0           ['Store_Embed[0][0]']
#
#  DayOfWeek_flat (Flatten)       (None, 2)            0           ['DayOfWeek_Embed[0][0]']
#
#  BeforeStateHoliday_bool_input   [(None, 1)]         0           []
#  (InputLayer)
#
#  Max_TemperatureC_input (InputL  [(None, 1)]         0           []
#  ayer)
#
#  All_Concatenate (Concatenate)  (None, 54)           0           ['Store_flat[0][0]',
#                                                                   'DayOfWeek_flat[0][0]',
#                                                                   'BeforeStateHoliday_bool_input[0
#                                                                  ][0]',
#                                                                   'Max_TemperatureC_input[0][0]']
#
#  dense_2 (Dense)                (None, 1000)         55000       ['All_Concatenate[0][0]']
#
#  activation_2 (Activation)      (None, 1000)         0           ['dense_2[0][0]']
#
#  dense_3 (Dense)                (None, 500)          500500      ['activation_2[0][0]']
#
#  activation_3 (Activation)      (None, 500)          0           ['dense_3[0][0]']
#
#  Sales (Dense)                  (None, 1)            501         ['activation_3[0][0]']
#
#  Customers (Dense)              (None, 1)            501         ['activation_3[0][0]']
#
# ==================================================================================================
# Total params: 612,266
# Trainable params: 612,266
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
model.save_weights('initial_weights.hdf5')

# %%
df_train = df[df.Date < datetime.datetime(2015, 7, 1)]  
df_val = df[df.Date >= datetime.datetime(2015, 7, 1)]
print(f'Cantidad en val: {len(df_val)}, porcentaje: {len(df_train)/(len(df_train) + len(df_val))}')
# Out:
# Cantidad en val: 30188, porcentaje: 0.9642465458145908

# %%
from matplotlib import pyplot as plt
# plt.figure(figsize=(20,5))
# plt.plot((df_train[df_train['Store']==1]['Sales'].values - df_train[df_train['Store']==1]['Sales'].mean())/df_train[df_train['Store']==1]['Sales'].std())
# plt.show()
# plt.figure(figsize=(20,5))
# plt.plot(np.log(df_train[df_train['Store']==1]['Sales'].values)/np.max(np.log(df_train[df_train['Store']==1]['Sales'].values)))
# plt.show()

# %%
stores_mean = {}
for store, g_df in df_train.groupby('Store'):
    stores_mean[store] = g_df[g_df['Sales'] > 0]['Sales'].mean()

# %%
df_train.loc[:, 'mean_by_store'] = df_train['Store'].apply(stores_mean.get)
df_val.loc[:, 'mean_by_store'] = df_val['Store'].apply(stores_mean.get)

df_train.loc[:, 'Sales_store'] = df_train['Sales'] - df_train['mean_by_store']
df_val.loc[:, 'Sales_store'] = df_val['Sales'] - df_val['mean_by_store']
# Out:
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1667: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = value

# %%
from tensorflow.keras import backend as K

# %%
def rmspe(y_true, y_pred):
    return K.sqrt(K.mean(K.square((y_true - y_pred)/y_true)))

# %%
def get_metric(df, sales_):
    return np.sqrt((((df['Sales'] - sales_)/df['Sales'])**2).mean())

# %%
get_metric(df_val, df_val['mean_by_store'])
# Out:
# 0.3071746085338871

# %%
all_vars = cat_vars + contin_vars
X_train = np.hsplit(df_train[all_vars].values, len(all_vars))
X_val = np.hsplit(df_val[all_vars].values, len(all_vars))
X_test = np.hsplit(df_test[all_vars].values, len(all_vars))

# %%
if add_customers:
    y_out_columns = ['Sales', 'Customers']
else:
    y_out_columns = ['Sales_store']
    
if log_output:
    # Escala logaritmica
    max_log_y = np.max(np.log(df[y_out_columns])).values
    y_train = np.log(df_train[y_out_columns].values)/max_log_y
    y_val = np.log(df_val[y_out_columns].values)/max_log_y
else:
    # Normalización
      y_mean = df_train[y_out_columns].mean().values
      y_std = df_train[y_out_columns].std().values
      y_train = (df_train[y_out_columns].values - y_mean)/y_std
      y_val = (df_val[y_out_columns].values - y_mean)/y_std
      y_max = df_train[y_out_columns].max().values
      y_train = df_train[y_out_columns].values/y_max
      y_val = df_val[y_out_columns].values/y_max
y_train = np.hsplit(y_train, y_train.shape[1])
y_val = np.hsplit(y_val, y_val.shape[1])

# %%
lr = 0.001
model.compile(optimizer=Adam(lr=lr), metrics=['mse', rmspe], loss='mse')
# Out:
# /usr/local/lib/python3.7/dist-packages/keras/optimizers/optimizer_v2/adam.py:110: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   super(Adam, self).__init__(name, **kwargs)

# %%
if add_customers:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_Sales_mse', verbose=1, save_best_only=True)
else:
    checkpoint = ModelCheckpoint('bestmodel.hdf5', monitor='val_loss', verbose=1, save_best_only=True)

# %%
epochs = 20
batch_size = 256
history = model.fit(X_train, y_train, validation_data=(X_val, y_val),  epochs=epochs, batch_size=batch_size, callbacks=[checkpoint], verbose=2)
# Out:
# Epoch 1/20
#
# Epoch 1: val_Sales_mse improved from inf to 0.00163, saving model to bestmodel.hdf5
# 3181/3181 - 91s - loss: 0.0065 - Sales_loss: 0.0023 - Customers_loss: 8.2688e-04 - Sales_mse: 0.0023 - Sales_rmspe: 0.3541 - Customers_mse: 8.2688e-04 - Customers_rmspe: 0.3187 - val_loss: 0.0025 - val_Sales_loss: 0.0016 - val_Customers_loss: 6.6889e-04 - val_Sales_mse: 0.0016 - val_Sales_rmspe: 0.2667 - val_Customers_mse: 6.6889e-04 - val_Customers_rmspe: 0.2675 - 91s/epoch - 28ms/step
# Epoch 2/20
#
# Epoch 2: val_Sales_mse improved from 0.00163 to 0.00150, saving model to bestmodel.hdf5
# 3181/3181 - 84s - loss: 0.0028 - Sales_loss: 0.0020 - Customers_loss: 6.1489e-04 - Sales_mse: 0.0020 - Sales_rmspe: 0.3321 - Customers_mse: 6.1489e-04 - Customers_rmspe: 0.2916 - val_loss: 0.0021 - val_Sales_loss: 0.0015 - val_Customers_loss: 3.8603e-04 - val_Sales_mse: 0.0015 - val_Sales_rmspe: 0.2391 - val_Customers_mse: 3.8603e-04 - val_Customers_rmspe: 0.2048 - 84s/epoch - 26ms/step
# Epoch 3/20
#
# Epoch 3: val_Sales_mse improved from 0.00150 to 0.00142, saving model to bestmodel.hdf5
# 3181/3181 - 78s - loss: 0.0026 - Sales_loss: 0.0019 - Customers_loss: 4.5590e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3226 - Customers_mse: 4.5590e-04 - Customers_rmspe: 0.2615 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.7722e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2382 - val_Customers_mse: 3.7722e-04 - val_Customers_rmspe: 0.2216 - 78s/epoch - 25ms/step
# Epoch 4/20
#
# Epoch 4: val_Sales_mse did not improve from 0.00142
# 3181/3181 - 82s - loss: 0.0025 - Sales_loss: 0.0019 - Customers_loss: 4.5113e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3184 - Customers_mse: 4.5113e-04 - Customers_rmspe: 0.2560 - val_loss: 0.0020 - val_Sales_loss: 0.0015 - val_Customers_loss: 3.8538e-04 - val_Sales_mse: 0.0015 - val_Sales_rmspe: 0.2349 - val_Customers_mse: 3.8538e-04 - val_Customers_rmspe: 0.2052 - 82s/epoch - 26ms/step
# Epoch 5/20
#
# Epoch 5: val_Sales_mse did not improve from 0.00142
# 3181/3181 - 78s - loss: 0.0025 - Sales_loss: 0.0019 - Customers_loss: 4.4573e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3116 - Customers_mse: 4.4573e-04 - Customers_rmspe: 0.2503 - val_loss: 0.0020 - val_Sales_loss: 0.0015 - val_Customers_loss: 3.8617e-04 - val_Sales_mse: 0.0015 - val_Sales_rmspe: 0.2494 - val_Customers_mse: 3.8617e-04 - val_Customers_rmspe: 0.2161 - 78s/epoch - 25ms/step
# Epoch 6/20
#
# Epoch 6: val_Sales_mse improved from 0.00142 to 0.00137, saving model to bestmodel.hdf5
# 3181/3181 - 79s - loss: 0.0024 - Sales_loss: 0.0019 - Customers_loss: 4.4230e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3078 - Customers_mse: 4.4230e-04 - Customers_rmspe: 0.2470 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 4.1999e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2372 - val_Customers_mse: 4.1999e-04 - val_Customers_rmspe: 0.2280 - 79s/epoch - 25ms/step
# Epoch 7/20
#
# Epoch 7: val_Sales_mse improved from 0.00137 to 0.00136, saving model to bestmodel.hdf5
# 3181/3181 - 83s - loss: 0.0024 - Sales_loss: 0.0019 - Customers_loss: 4.3294e-04 - Sales_mse: 0.0019 - Sales_rmspe: 0.3057 - Customers_mse: 4.3294e-04 - Customers_rmspe: 0.2411 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.5004e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2327 - val_Customers_mse: 3.5004e-04 - val_Customers_rmspe: 0.1970 - 83s/epoch - 26ms/step
# Epoch 8/20
#
# Epoch 8: val_Sales_mse did not improve from 0.00136
# 3181/3181 - 81s - loss: 0.0024 - Sales_loss: 0.0018 - Customers_loss: 4.2757e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.3030 - Customers_mse: 4.2757e-04 - Customers_rmspe: 0.2369 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.3081e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2473 - val_Customers_mse: 3.3081e-04 - val_Customers_rmspe: 0.1934 - 81s/epoch - 26ms/step
# Epoch 9/20
#
# Epoch 9: val_Sales_mse improved from 0.00136 to 0.00136, saving model to bestmodel.hdf5
# 3181/3181 - 83s - loss: 0.0024 - Sales_loss: 0.0018 - Customers_loss: 4.1966e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.3003 - Customers_mse: 4.1966e-04 - Customers_rmspe: 0.2320 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.6369e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2438 - val_Customers_mse: 3.6369e-04 - val_Customers_rmspe: 0.2112 - 83s/epoch - 26ms/step
# Epoch 10/20
#
# Epoch 10: val_Sales_mse did not improve from 0.00136
# 3181/3181 - 78s - loss: 0.0023 - Sales_loss: 0.0018 - Customers_loss: 4.0928e-04 - Sales_mse: 0.0018 - Sales_rmspe: 0.2963 - Customers_mse: 4.0928e-04 - Customers_rmspe: 0.2251 - val_loss: 0.0018 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.2393e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2180 - val_Customers_mse: 3.2393e-04 - val_Customers_rmspe: 0.1816 - 78s/epoch - 25ms/step
# Epoch 11/20
#
# Epoch 11: val_Sales_mse improved from 0.00136 to 0.00131, saving model to bestmodel.hdf5
# 3181/3181 - 82s - loss: 0.0023 - Sales_loss: 0.0017 - Customers_loss: 3.8148e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2872 - Customers_mse: 3.8148e-04 - Customers_rmspe: 0.2143 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.0147e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2185 - val_Customers_mse: 3.0147e-04 - val_Customers_rmspe: 0.1678 - 82s/epoch - 26ms/step
# Epoch 12/20
#
# Epoch 12: val_Sales_mse did not improve from 0.00131
# 3181/3181 - 78s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.7283e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2841 - Customers_mse: 3.7283e-04 - Customers_rmspe: 0.2108 - val_loss: 0.0019 - val_Sales_loss: 0.0014 - val_Customers_loss: 3.7719e-04 - val_Sales_mse: 0.0014 - val_Sales_rmspe: 0.2273 - val_Customers_mse: 3.7719e-04 - val_Customers_rmspe: 0.1818 - 78s/epoch - 25ms/step
# Epoch 13/20
#
# Epoch 13: val_Sales_mse improved from 0.00131 to 0.00129, saving model to bestmodel.hdf5
# 3181/3181 - 78s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.7071e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2827 - Customers_mse: 3.7071e-04 - Customers_rmspe: 0.2101 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.0854e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2137 - val_Customers_mse: 3.0854e-04 - val_Customers_rmspe: 0.1793 - 78s/epoch - 25ms/step
# Epoch 14/20
#
# Epoch 14: val_Sales_mse did not improve from 0.00129
# 3181/3181 - 82s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6996e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2823 - Customers_mse: 3.6996e-04 - Customers_rmspe: 0.2100 - val_loss: 0.0018 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.6080e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2207 - val_Customers_mse: 3.6080e-04 - val_Customers_rmspe: 0.2057 - 82s/epoch - 26ms/step
# Epoch 15/20
#
# Epoch 15: val_Sales_mse did not improve from 0.00129
# 3181/3181 - 78s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6956e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2819 - Customers_mse: 3.6956e-04 - Customers_rmspe: 0.2095 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.0076e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2068 - val_Customers_mse: 3.0076e-04 - val_Customers_rmspe: 0.1698 - 78s/epoch - 24ms/step
# Epoch 16/20
#
# Epoch 16: val_Sales_mse did not improve from 0.00129
# 3181/3181 - 82s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6903e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2814 - Customers_mse: 3.6903e-04 - Customers_rmspe: 0.2094 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.3798e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2214 - val_Customers_mse: 3.3798e-04 - val_Customers_rmspe: 0.1920 - 82s/epoch - 26ms/step
# Epoch 17/20
#
# Epoch 17: val_Sales_mse did not improve from 0.00129
# 3181/3181 - 78s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6813e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2812 - Customers_mse: 3.6813e-04 - Customers_rmspe: 0.2094 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 2.9490e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2150 - val_Customers_mse: 2.9490e-04 - val_Customers_rmspe: 0.1710 - 78s/epoch - 24ms/step
# Epoch 18/20
#
# Epoch 18: val_Sales_mse improved from 0.00129 to 0.00128, saving model to bestmodel.hdf5
# 3181/3181 - 82s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6657e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2811 - Customers_mse: 3.6657e-04 - Customers_rmspe: 0.2087 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.1941e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2180 - val_Customers_mse: 3.1941e-04 - val_Customers_rmspe: 0.1853 - 82s/epoch - 26ms/step
# Epoch 19/20
#
# Epoch 19: val_Sales_mse improved from 0.00128 to 0.00127, saving model to bestmodel.hdf5
# 3181/3181 - 79s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6529e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2808 - Customers_mse: 3.6529e-04 - Customers_rmspe: 0.2080 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.0409e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2156 - val_Customers_mse: 3.0409e-04 - val_Customers_rmspe: 0.1781 - 79s/epoch - 25ms/step
# Epoch 20/20
#
# Epoch 20: val_Sales_mse improved from 0.00127 to 0.00126, saving model to bestmodel.hdf5
# 3181/3181 - 79s - loss: 0.0022 - Sales_loss: 0.0017 - Customers_loss: 3.6372e-04 - Sales_mse: 0.0017 - Sales_rmspe: 0.2804 - Customers_mse: 3.6372e-04 - Customers_rmspe: 0.2083 - val_loss: 0.0017 - val_Sales_loss: 0.0013 - val_Customers_loss: 3.0283e-04 - val_Sales_mse: 0.0013 - val_Sales_rmspe: 0.2122 - val_Customers_mse: 3.0283e-04 - val_Customers_rmspe: 0.1809 - 79s/epoch - 25ms/step

# %%
plt.plot(history.history['val_loss'])
# plt.plot(history.history['val_Customers_mse'])
# plt.plot(history.history['val_Sales_mse'])
plt.show()
plt.plot(history.history['loss'])
# plt.plot(history.history['Customers_mse'])
# plt.plot(history.history['Sales_mse'])

# %% [markdown]
# #Metrica

# %% [markdown]
# $$
# \textrm{RMSE} = \sqrt{\frac{1}{n} \sum_{i=1}^{n} \left(\frac{\hat{y}_i - y_i}{y_i}\right)^2}
# $$

# %%
model.evaluate(X_val, y_val)
# Out:
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0017 - Sales_loss: 0.0013 - Customers_loss: 3.0283e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2081 - Customers_mse: 3.0283e-04 - Customers_rmspe: 0.1763
# [0.0016625489806756377,
#  0.0012600652407854795,
#  0.00030282780062407255,
#  0.0012600652407854795,
#  0.2080647200345993,
#  0.00030282780062407255,
#  0.17630691826343536]

# %%
model.load_weights('bestmodel.hdf5')
model.evaluate(X_val, y_val)
# Out:
# 944/944 [==============================] - 4s 4ms/step - loss: 0.0017 - Sales_loss: 0.0013 - Customers_loss: 3.0283e-04 - Sales_mse: 0.0013 - Sales_rmspe: 0.2081 - Customers_mse: 3.0283e-04 - Customers_rmspe: 0.1763
# [0.0016625489806756377,
#  0.0012600652407854795,
#  0.00030282780062407255,
#  0.0012600652407854795,
#  0.2080647200345993,
#  0.00030282780062407255,
#  0.17630691826343536]

# %%
if log_output:
    if add_customers:
        y_pred = np.exp(model.predict(X_val, verbose=1)[0][:, 0]*max_log_y[0])
        y_pred_test = np.exp(model.predict(X_test, verbose=1)[0][:, 0]*max_log_y[0])
    else:
        y_pred = np.exp(model.predict(X_val, verbose=1)*max_log_y)[:,0]
        y_pred_test = np.exp(model.predict(X_test, verbose=1)*max_log_y)[:,0]
else:
    if add_customers:
        y_pred = (model.predict(X_val, verbose=1)[0]*y_std[0] + y_mean[0])[:,0]
        y_pred_test = (model.predict(X_test, verbose=1)[0]*y_std[0] + y_mean[0])[:,0]
    else:
#         y_pred = model.predict(X_val, verbose=1)[:,0]*y_std + y_mean
#         y_pred_test = model.predict(X_test, verbose=1)[:,0]*y_std + y_mean
        y_pred = model.predict(X_val, verbose=1)[:,0]*y_max
        y_pred_test = model.predict(X_test, verbose=1)[:,0]*y_max
y_pred_test[df_test['Open'] == 0] = 0
# Out:
# 944/944 [==============================] - 3s 3ms/step
# 1284/1284 [==============================] - 5s 4ms/step

# %%
np.sqrt((((df_val['Sales'].values - y_pred)/df_val['Sales'].values)**2).sum()/len(y_pred))
# Out:
# 0.5840832807353887

# %%
y_pred_test[:10]
# Out:
# array([7304.5083, 7517.8403, 7669.6567, 7412.5337, 7458.911 , 7382.77  ,
#        7611.083 , 7556.7607, 7303.8823, 7396.3267], dtype=float32)

# %% [markdown]
# #Baseline

# %%
import pandas as pd
sample_csv = pd.read_csv('/gdrive/Shareddrives/Redes de Piluchina/TP 2_final/dataset/sample_submission.csv')

# %%
stores_mean = {}
for store, g_df in df.groupby('Store'):
    stores_mean[store] = g_df[g_df['Sales'] > 0]['Sales'].mean()

# %%
df_test['Sales'] = df_test['Store'].apply(stores_mean.get)
df_test.loc[df_test['Open'] == 0, 'Sales'] = 0

# %%
df_test[['Store', 'Sales']].head(10)
# Out:
#    Store        Sales
# 0      0  4759.096031
# 1      2  6942.568678
# 2      6  8817.050891
# 3      7  5539.358418
# 4      8  6562.337612
# 5      9  5568.420918
# 6     10  8030.977041
# 7     11  7589.598214
# 8     12  5034.747182
# 9     13  5508.567394

# %%
df_test[df_test['Open'] == 0][['Store', 'Sales']].head()
# Out:
#       Store  Sales
# 543     702    0.0
# 676     878    0.0
# 840    1096    0.0
# 1399    702    0.0
# 1532    878    0.0

# %%
sample_csv['Sales'] = df_test['Sales']

# %%
sample_csv.to_csv(f'submision_baseline.csv', index=False)

# %%
sample_csv.head()
# Out:
#    Id        Sales
# 0   1  4759.096031
# 1   2  6942.568678
# 2   3  8817.050891
# 3   4  5539.358418
# 4   5  6562.337612

# %% [markdown]
# #Sumbit a la competición

# %%
sample_csv = pd.read_csv('/gdrive/Shareddrives/Redes de Piluchina/TP 2_final/dataset/sample_submission.csv')
sample_csv['Sales'] = y_pred_test
sample_csv.head()

sample_csv.to_csv(f'/gdrive/Shareddrives/Redes de Piluchina/TP 2_final/submision_{add_customers}-{log_output}-{output_activation}-{l2_lambda}-{first_hidden_units}-{epochs}-{batch_size}-{lr}.csv', index=False)

# %% [markdown]
# #Analisis de embedings

# %%
def plot_embed(layer_name, cat_names):
    Y = model.get_layer(layer_name).get_weights()[0]
    print(Y.shape)
    plt.figure(figsize=(8,8))
    plt.scatter(-Y[:, 0], -Y[:, 1])
    for i, txt in enumerate(cat_names):
        plt.annotate(txt, (-Y[i, 0],-Y[i, 1]), xytext = (-5, 8), textcoords = 'offset points')

# %%
model.load_weights('bestmodel.hdf5')
plot_embed('DayOfWeek_Embed', ['Mon', 'Tue', 'Wed', 'Thu', 'Fri', 'Sat','Sun'])
# Out:
# (7, 2)

# %%
from sklearn.manifold import TSNE
from sklearn.decomposition import PCA

# %%
cat_vars
# Out:
# ['Store', 'DayOfWeek']

# %%
submodel = Model(cat_var_inputs + cont_vars_inputs, merged)

# %%
submodel.summary()
# Out:
# Model: "model_3"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  Store_input (InputLayer)       [(None, 1)]          0           []
#
#  DayOfWeek_input (InputLayer)   [(None, 1)]          0           []
#
#  Store_Embed (Embedding)        (None, 1, 50)        55750       ['Store_input[0][0]']
#
#  DayOfWeek_Embed (Embedding)    (None, 1, 2)         14          ['DayOfWeek_input[0][0]']
#
#  Store_flat (Flatten)           (None, 50)           0           ['Store_Embed[0][0]']
#
#  DayOfWeek_flat (Flatten)       (None, 2)            0           ['DayOfWeek_Embed[0][0]']
#
#  BeforeStateHoliday_bool_input   [(None, 1)]         0           []
#  (InputLayer)
#
#  Max_TemperatureC_input (InputL  [(None, 1)]         0           []
#  ayer)
#
#  All_Concatenate (Concatenate)  (None, 54)           0           ['Store_flat[0][0]',
#                                                                   'DayOfWeek_flat[0][0]',
#                                                                   'BeforeStateHoliday_bool_input[0
#                                                                  ][0]',
#                                                                   'Max_TemperatureC_input[0][0]']
#
# ==================================================================================================
# Total params: 55,764
# Trainable params: 55,764
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
submodel.save('embeddings_model.hdf5')
# Out:
# WARNING:tensorflow:Compiled the loaded model, but the compiled metrics have yet to be built. `model.compile_metrics` will be empty until you train or evaluate the model.

# %%
pip freeze > requirements.txt
